# %% [markdown]
# <a href="https://colab.research.google.com/github/FerdousJUST/InceptionV3-model-implementation-for-Fish-Image-Classification-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
import glob

# %%
TRAIN_DIR = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 "
ORG_DIR = " /content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training"
CLASS = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']

# %%
for c in CLASS: 
  DEST = os.path.join(TRAIN_DIR,c)
  if not os.path.exists(DEST):
    os.makedirs(DEST)

  for img_path in glob.glob(os.path.join(ORG_DIR,c)+ " * "):
    SRC = img_path
    shutil.copy(SRC,DEST)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

from keras.layers import Dense,Flatten
from keras.models import Model  
from keras.applications.inception_v3 import InceptionV3,preprocess_input
from keras.preprocessing.image import ImageDataGenerator
import keras

# %%
base_model = InceptionV3(input_shape = (256,256,3),include_top= False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
x = Flatten()(base_model.output)
x = Dense(units = 4, activation = 'softmax')(x)

model = Model(base_model.input,x)
#model.compile(optimizer = 'adam',loss= 'sparse_categorical_crossentropy ',metrics = ['accuracy'])
model.compile(optimizer = 'adam',loss = keras.losses.binary_crossentropy,metrics = ['accuracy'])

# %%
train_datagen = ImageDataGenerator(featurewise_center= True,
                                   rotation_range = 0.4,
                                   width_shift_range=0.3,
                                   horizontal_flip=True,
                                   preprocessing_function=preprocess_input,
                                   zoom_range = 0.4,
                                   shear_range = 0.4 )
train_data = train_datagen.flow_from_directory(TRAIN_DIR,
                                               target_size = (256,256),
                                               batch_size = 36)
# Out:
# Found 4800 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'Barbel_Fish': 0,
#  'Hilsha_Fish': 1,
#  'Spotted_Snakehead_Fish': 2,
#  'Tilapia_Fish': 3}

# %%
t_img,label = train_data.next()
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py:1663: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
t_img.shape
# Out:
# (36, 256, 256, 3)

# %%
def plotImages (img_arr,label):
  for idx,img in enumerate(img_arr):
    if idx <= 10:
      plt.figure(figsize = (5,5))
      plt.imshow(img)
      plt.title(img.shape)
      plt.axis = False
      plt.show()

# %%
plotImages(t_img,label)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
mc = ModelCheckpoint(filepath = " /content/drive/Shareddrives/Research Collaboration/Ferdous MSc Project/part eleven/inception_model.h5",
                      monitor = " accuracy",
                      varbose = 2,
                      save_best_only = True)

es = EarlyStopping(monitor = "accuracy",
                   min_delta = 0.001,
                   patience=5,
                   verbose = 2)
cb = [mc,es]

# %%
import tensorflow as tf

from keras.models import load_model

model.save('/content/drive/Shareddrives/Research Collaboration/Ferdous MSc Project/part eleven/inception_model(1).h5')

# %%
from keras import callbacks
his = model.fit_generator(train_data,
                          steps_per_epoch = 10,
                          epochs = 10,
                          callbacks = cb
                          )
# Out:
# <ipython-input-16-6ebe036767e1>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   his = model.fit_generator(train_data,
# Epoch 1/10
# 10/10 [==============================] - ETA: 0s - loss: 2.6555 - accuracy: 0.5444
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 124s 11s/step - loss: 2.6555 - accuracy: 0.5444
# Epoch 2/10
# 10/10 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.8944
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 106s 10s/step - loss: 0.4754 - accuracy: 0.8944
# Epoch 3/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9194
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 97s 9s/step - loss: 0.2949 - accuracy: 0.9194
# Epoch 4/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2828 - accuracy: 0.9167
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 88s 8s/step - loss: 0.2828 - accuracy: 0.9167
# Epoch 5/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9286
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 85s 8s/step - loss: 0.2245 - accuracy: 0.9286
# Epoch 6/10
# 10/10 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9528
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 80s 8s/step - loss: 0.1943 - accuracy: 0.9528
# Epoch 7/10
# 10/10 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9694
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 76s 7s/step - loss: 0.1534 - accuracy: 0.9694
# Epoch 8/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9639
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 72s 7s/step - loss: 0.0997 - accuracy: 0.9639
# Epoch 9/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9722
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 72s 7s/step - loss: 0.0847 - accuracy: 0.9722
# Epoch 10/10
# 10/10 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9792
# WARNING:tensorflow:Can save best model only with  accuracy available, skipping.
# 10/10 [==============================] - 62s 6s/step - loss: 0.0600 - accuracy: 0.9792

# %%
h = his.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.figure(figsize = (8,6))
plt.plot(his.history['loss'],'b-o',color = 'blue',label = 'train',linewidth=3.0)
plt.plot(his.history['accuracy'],'b-o',color = 'orange',label = 'train',linewidth=3.0)
plt.grid(True)
epochs = range(1,20)
plt.legend(['Training Loss', 'Training Accuracy'], loc='center right')
plt.title("Training Loss and Training Accuracy with Epochs\n",fontsize = 16)
plt.xlabel("Training Epochs",fontsize= 16)
plt.ylabel("Train & Test Level",fontsize =16)
plt.show()

# %%
from keras.utils.image_utils import img_to_array,load_img
path = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 /Tilapia_Fish/Tilapia_Fish 007.png"
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i = preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))
if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")
# Out:
# 1/1 [==============================] - 2s 2s/step
# Tilapia Fish

# %%
from keras.utils.image_utils import img_to_array,load_img
path = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 /Barbel_Fish/Barbel_Fish 011.jpg"
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i = preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))
if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")
# Out:
# 1/1 [==============================] - 0s 230ms/step
# Barbel Fish

# %%
from keras.utils.image_utils import img_to_array,load_img
path = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 /Hilsha_Fish/Hilsha_Fish 006.jpg"
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i = preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))
if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")
# Out:
# 1/1 [==============================] - 0s 213ms/step
# Hilsha Fish

# %%
from keras.utils.image_utils import img_to_array,load_img
path = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 /Spotted_Snakehead_Fish/Spotted_Fish 006.jpg"
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i = preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))
if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")
# Out:
# 1/1 [==============================] - 0s 216ms/step
# Spotted Snakehead Fish

# %%
from keras.utils.image_utils import img_to_array,load_img
path = "/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training1 /Tilapia_Fish/Tilapia_Fish 007.png"
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i = preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))
if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")
# Out:
# 1/1 [==============================] - 0s 224ms/step
# Tilapia Fish

# %%
import matplotlib.cm as cm 
from IPython.display import Image,display

# %%
def make_gradcam_heatmap(img_arr,model,last_conv_layer_name,pred_index = None):
  grad_model = tf.keras.models.Model(
    [model.input],[model.get_layer(last_conv_layer_name).output,model.output]

  )

  with tf.GradientTape() as tape:
    last_conv_layer_output,preds = grad_model(img_arr)

    if pred_index is None:
      pred_index = tf.argmax(preds[0])
                             
    class_channel = preds[:,pred_index]

    grads = tape.gradient(class_channel,last_conv_layer_output)  
    pooled_grads = tf.reduce_mean(grads,axis = (0,1,2))

    last_conv_layer_output = last_conv_layer_output[0]

    heatmap = last_conv_layer_output @ pooled_grads[...,tf.newaxis]

    heatmap = tf.squeeze(heatmap)

    heatmap = tf.maximum(heatmap,0)/tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
from keras.utils.image_utils import img_to_array,load_img

def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = load_img(img_path, target_size=(299,299))
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# The local path to our target image
#img_path = keras.utils.get_file(
    #"Barbel fish.jpg", "/content/barbel1.jpg"
#)
img_path = "/content/hilsha1.jpg"

display(Image(img_path))

# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02514041', 'barracouta', 5.9867835)]

# %%
def get_img_arr(img_path):
  img = load_img(path,target_size=(256,256))
  img = img_to_array(img)
  img = preprocess_input(img)
  img = np.array([img])
  return img

# %%
import tensorflow as tf

# %%
def make_gradcam_heatmap(img_arr,model,last_conv_layer_name,pred_index = None):
  grad_model = tf.keras.models.Model(
    [model.input],[model.get_layer(last_conv_layer_name).output,model.output]

  )

  with tf.GradientTape() as tape:
    last_conv_layer_output,preds = grad_model(img_arr)

    if pred_index is None:
      pred_index = tf.argmax(preds[0])
                             
    class_channel = preds[:,pred_index]

    grads = tape.gradient(class_channel,last_conv_layer_output)  
    pooled_grads = tf.reduce_mean(grads,axis = (0,1,2))

    last_conv_layer_output = last_conv_layer_output[0]

    heatmap = last_conv_layer_output @ pooled_grads[...,tf.newaxis]

    heatmap = tf.squeeze(heatmap)

    heatmap = tf.maximum(heatmap,0)/tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
import matplotlib.cm as cm 
from IPython.display import Image,display

# %%
from keras.utils.image_utils import img_to_array,load_img





def save_and_display_gradcam(img_path,heatmap,cam_path = "cam.jpg",alpha = 0.4):
  img = img_to_array(load_img(img_path))
  heatmap = np.uint8(255*heatmap)
  jet = cm.get_cmap("jet")

  jet_colors = jet(np.arange(256))[:,:3]
  jet_heatmap = jet_colors[heatmap]


  jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
  jet_heatmap = jet_heatmap.resize((img.shape[1],img.shape[0]))
  jet_heatmap = img_to_array(jet_heatmap)


  superimposed_img = jet_heatmap * alpha + img
  superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

  superimposed_img.save(cam_path)

  display(Image(cam_path)) 
  save_and_display_gradcam(img_path, heatmap)

# %%
def image_prediction_and_visualization(path,last_conv_layer_name = "conv2d_93",model = model):
  img_array = get_img_arr(path)

  heatmap = make_gradcam_heatmap(img_array,model,last_conv_layer_name)

  plt.title("the heat map of the image is: ")
  plt.imshow(heatmap)
  plt.show()

  pred = np.argmax(model.predict(preprocess_input(img_array)))
  print()
  print()
  print()

if pred == 0:
  print("Barbel Fish")
elif pred==1:
  print("Hilsha Fish")
elif pred==2:
  print("Spotted Snakehead Fish")
elif pred==3:
  print("Tilapia Fish")

print()
print()
print()

print("image with heatmap reporting region on interest")


#save_and_display_gradcam(path,heatmap)

print()
print("the original input image")
print()
a= plt.imread(path)
plt.imshow(a,cmap = "gray")
plt.title("Original Image")
plt.show()



path = "/content/hilsha1.jpg"
image_prediction_and_visualization(path)
# Out:
# Tilapia Fish
#
#
#
# image with heatmap reporting region on interest
#
# the original input image
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-a37699b31163> in <module>
#      42
#      43 path = "/content/hilsha1.jpg"
# ---> 44 image_prediction_and_visualization(path)
#
# <ipython-input-46-a37699b31163> in image_prediction_and_visualization(path, last_conv_layer_name, model)
#       2   img_array = get_img_arr(path)
#       3
# ----> 4   heatmap = make_gradcam_heatmap(img_array,model,last_conv_layer_name)
#       5
#       6   plt.title("the heat map of the image is: ")
#
# <ipython-input-31-fa3c3e1065de> in make_gradcam_heatmap(img_arr, model, last_conv_layer_name, pred_index)
#       1 def make_gradcam_heatmap(img_arr,model,last_conv_layer_name,pred_index = None):
#       2   grad_model = tf.keras.models.Model(
# ----> 3     [model.input],[model.get_layer(last_conv_layer_name).output,model.output]
#       4
#       5   )
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in get_layer(self, name, index)
#    2920         if layer.name == name:
#    2921           return layer
# -> 2922       raise ValueError(f'No such layer: {name}. Existing layers are: '
#    2923                        f'{list(layer.name for layer in self.layers)}.')
#    2924     raise ValueError('Provide either a layer name or layer index at '
#
# ValueError: No such layer: conv2d_93. Existing layers are: ['input_3', 'block1_conv1', 'block1_conv1_bn', 'block1_conv1_act', 'block1_conv2', 'block1_conv2_bn', 'block1_conv2_act', 'block2_sepconv1', 'block2_sepconv1_bn', 'block2_sepconv2_act', 'block2_sepconv2', 'block2_sepconv2_bn', 'conv2d_98', 'block2_pool', 'batch_normalization_98', 'add_12', 'block3_sepconv1_act', 'block3_sepconv1', 'block3_sepconv1_bn', 'block3_sepconv2_act', 'block3_sepconv2', 'block3_sepconv2_bn', 'conv2d_99', 'block3_pool', 'batch_normalization_99', 'add_13', 'block4_sepconv1_act', 'block4_sepconv1', 'block4_sepconv1_bn', 'block4_sepconv2_act', 'block4_sepconv2', 'block4_sepconv2_bn', 'conv2d_100', 'block4_pool', 'batch_normalization_100', 'add_14', 'block5_sepconv1_act', 'block5_sepconv1', 'block5_sepconv1_bn', 'block5_sepconv2_act', 'block5_sepconv2', 'block5_sepconv2_bn', 'block5_sepconv3_act', 'block5_sepconv3', 'block5_sepconv3_bn', 'add_15', 'block6_sepconv1_act', 'block6_sepconv1', 'block6_sepconv1_bn', 'block6_sepconv2_act', 'block6_sepconv2', 'block6_sepconv2_bn', 'block6_sepconv3_act', 'block6_sepconv3', 'block6_sepconv3_bn', 'add_16', 'block7_sepconv1_act', 'block7_sepconv1', 'block7_sepconv1_bn', 'block7_sepconv2_act', 'block7_sepconv2', 'block7_sepconv2_bn', 'block7_sepconv3_act', 'block7_sepconv3', 'block7_sepconv3_bn', 'add_17', 'block8_sepconv1_act', 'block8_sepconv1', 'block8_sepconv1_bn', 'block8_sepconv2_act', 'block8_sepconv2', 'block8_sepconv2_bn', 'block8_sepconv3...
